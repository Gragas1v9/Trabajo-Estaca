# %% [markdown]
# # NOTEBOOK GRUPO 11 ESTADISTICA COMPUTACIONAL

# %% [markdown]
# ## Introducción
#
# Para el desarrollo del proyecto seleccionamos el dataset “Student Habits vs Academic Performance”. Este conjunto de datos contiene aproximadamente 1 000 observaciones sobre estudiantes, incluyendo información relacionada con sus hábitos diarios (horas de estudio, tiempo en redes sociales, calidad del sueño, nivel de estrés, actividad física, entre otros) junto con su puntaje final de examen.
#
# La elección de este dataset se fundamenta en su relevancia académica y social, ya que permite analizar cómo distintos factores de comportamiento y estilo de vida influyen en el rendimiento académico. Este tipo de estudio resulta de gran interés en ámbitos como la educación, la psicología y la salud pública, y ofrece la posibilidad de identificar patrones que podrían servir de base para recomendaciones prácticas a estudiantes y docentes.

# %% [markdown]
# ### Inicialización

# %%
# !pip install seaborn
# !pip install pandas
# !pip install matplotlib
# !pip install numpy
# !pip install scipy
# Out:
# Requirement already satisfied: seaborn in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: C:\Users\Héctor Chanampe\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.3.2)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: C:\Users\Héctor Chanampe\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: C:\Users\Héctor Chanampe\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.3.2)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: C:\Users\Héctor Chanampe\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting scipy
#   Downloading scipy-1.16.2-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\users\héctor chanampe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scipy) (2.3.2)
# Downloading scipy-1.16.2-cp311-cp311-win_amd64.whl (38.7 MB)
#    ---------------------------------------- 0.0/38.7 MB ? eta -:--:--
#    - -------------------------------------- 1.6/38.7 MB 8.4 MB/s eta 0:00:05
#    --- ------------------------------------ 3.1/38.7 MB 8.0 MB/s eta 0:00:05
#    ----- ---------------------------------- 5.0/38.7 MB 8.0 MB/s eta 0:00:05
#    ------ --------------------------------- 6.6/38.7 MB 8.1 MB/s eta 0:00:04
#    -------- ------------------------------- 7.9/38.7 MB 7.5 MB/s eta 0:00:05
#    --------- ------------------------------ 9.4/38.7 MB 7.6 MB/s eta 0:00:04
#    ----------- ---------------------------- 11.3/38.7 MB 7.7 MB/s eta 0:00:04
#    ------------- -------------------------- 13.1/38.7 MB 7.8 MB/s eta 0:00:04
#    --------------- ------------------------ 14.7/38.7 MB 7.8 MB/s eta 0:00:04
#    ----------------- ---------------------- 16.5/38.7 MB 7.8 MB/s eta 0:00:03
#    ------------------ --------------------- 17.8/38.7 MB 7.9 MB/s eta 0:00:03
#    -------------------- ------------------- 19.7/38.7 MB 7.8 MB/s eta 0:00:03
#    --------------------- ------------------ 21.2/38.7 MB 7.8 MB/s eta 0:00:03
#    ----------------------- ---------------- 22.8/38.7 MB 7.8 MB/s eta 0:00:03
#    ------------------------- -------------- 24.6/38.7 MB 7.8 MB/s eta 0:00:02
#    --------------------------- ------------ 26.2/38.7 MB 7.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 28.0/38.7 MB 7.9 MB/s eta 0:00:02
#    ------------------------------ --------- 29.6/38.7 MB 7.9 MB/s eta 0:00:02
#    -------------------------------- ------- 31.5/38.7 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.0/38.7 MB 7.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.6/38.7 MB 7.9 MB/s eta 0:00:01
#    ------------------------------------- -- 36.4/38.7 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.7 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------- 38.7/38.7 MB 7.7 MB/s eta 0:00:00
# Installing collected packages: scipy
# Successfully installed scipy-1.16.2
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: C:\Users\Héctor Chanampe\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv('student_habits_performance.csv')
print("Pandas funciona versión:", pd.__version__)
# Out:
# Pandas funciona versión: 2.3.2

# %% [markdown]
# ## PRIMERA ENTREGA

# %% [markdown]
# ### Sobre los datos y nuestra motivación
# El dataset *"Strudent Habits vs Academic Performance"*, es una simulación de datos basados en comportamiento realista en estudiantes *college*.
# Estos datos toman una colección de comportamientos de la rutina diaria y las notas de los estudiantes.
# Como grupo estamos interesados en buscar alguna correlación entre estos hábitos y las calificaciones ya que podrían indicar correlaciones que podrían ser interesantes de investigar.
# **Variables:**
#     **- Edad:** Edad del estudiante.
#     **- Género:** Genero del estudiante.
#     **- Horas de estudio:** Horas que el estudiante dedica a estudiar diariamente.
#     **- Redes Sociales:** Horas diarias de uso de redes sociales.
#     **- Netflix:** Horas diarias de visualización de netflix.
#     **- Trabajo a medio tiempo:** Si/No tiene un trabajo a medio tiempo.
#     **- Asistencia:** Porcentaje de asistencia a clases.
#     **- Horas de sueño:** Horas de sueño diarias.
#     **- Dieta:** Good/Fair/Poor, indica la calidad de su dieta alimenticia.
#     **- Frecuecia de ejercicio:** Cantidad de veces por semana que la persona realiza actividad física..
#     **- Educación de los padres:** Nivel más alto de educación alcanzado por los padres.
#     **- Internet:** Good/Average/Poor Calidad del internet.
#     **- Salud Mental:** Evaluación, del 1 al 10, de su salud mental.
#     **- Extracurricular:** Si/No participa en actividades extracurriculares.
#     **- Nota:** Nota de su exámen.

# %% [markdown]
# ### LIMPIEZA DE DATOS
# El dataset elegido cuenta con 1000 observaciones y 16 columnas.
# Analizamos el dataset en busca de datos nulos, se eliminaran las observaciones que tengan datos nulos en algunas de sus columnas.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
#  12  internet_quality               1000 non-null   object
#  13  mental_health_rating           1000 non-null   int64
#  14  extracurricular_participation  1000 non-null   object
#  15  exam_score                     1000 non-null   float64
# dtypes: float64(6), int64(3), object(7)
# memory usage: 125.1+ KB

# %% [markdown]
# Podemos notar que en la columna ***parental_education_level*** existen 91 observaciones que tienen ese campo nulo.
# Eliminamos las observaciones nulas con `df.dropna()`

# %%
df = df.dropna()
print("Filas:",df.shape[0])
print("Columnas:",df.shape[1])
print("\nEsta es una muestra de como se ven los datos:")
df.head()
# Out:
# Filas: 909
# Columnas: 16
#
# Esta es una muestra de como se ven los datos:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
# 2         Poor                   1              High School             Poor
# 3         Poor                   4                   Master             Good
# 4         Fair                   3                   Master             Good
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0
# 2                     1                            No        34.3
# 3                     1                           Yes        26.8
# 4                     1                            No        66.4

# %% [markdown]
# ### Descripición de las variables y los datos
# Primero crearemos un diccionario para poder identificar los tipos de variables que trabajaremos. El diccionario guardará como key el nombre de la columna y como valor el tipo de dato de la variable, las que podrán ser:
# * Categóricas
# * Discretas
# * Continuas
#
# También crearemos una lista por cada tipo de variable.

# %%
dict_TipoVariable={}
varCategoricas=[]
varDiscretas=[]
varContinuas=[]
for columna, tipo in df.dtypes.items():
    if (tipo=="object"):
        dict_TipoVariable[columna]="Categorica"
        varCategoricas.append(columna)
    elif(tipo=="int64"):
        dict_TipoVariable[columna]="Discreta"
        varDiscretas.append(columna)
    else:
        dict_TipoVariable[columna]="Continua"
        varContinuas.append(columna)

print("Variables categóricas: ",varCategoricas)
print("Variables continuas: ",varContinuas)
print("Variables discretas:", varDiscretas)
# Out:
# Variables categóricas:  ['student_id', 'gender', 'part_time_job', 'diet_quality', 'parental_education_level', 'internet_quality', 'extracurricular_participation']
# Variables continuas:  ['study_hours_per_day', 'social_media_hours', 'netflix_hours', 'attendance_percentage', 'sleep_hours', 'exam_score']
# Variables discretas: ['age', 'exercise_frequency', 'mental_health_rating']

# %% [markdown]
# ### Estadísticos

# %% [markdown]
# #### min, max, promedio y correlacion
# Calculamos el mínimo, máximo y promedio de cada variable numérica existente en nuestro dataset.
# En la celda subsiguiente calculamos la correlación entre las variables. Los datos de la correlación varían entre -1 y 1.
# * Valores cercanos a 1 en la correlación indican que existe una tendencia directamente proporcional entre los datos.
# * Valores cercanos a -1 indican la existencia de una tendencia inversamente proporcional entre los datos.
# * Valores cercanos a 0 indican que los datos no tienen implicancia entre sí.

# %%
varNumericas = varContinuas+varDiscretas
df[varNumericas].agg(["min","max","mean"]).T
# Out:
#                         min    max       mean
# study_hours_per_day     0.0    8.3   3.538724
# social_media_hours      0.0    7.2   2.504620
# netflix_hours           0.0    5.4   1.830363
# attendance_percentage  56.0  100.0  83.880308
# sleep_hours             3.2   10.0   6.474037
# exam_score             18.4  100.0  69.558196
# age                    17.0   24.0  20.475248
# exercise_frequency      0.0    6.0   3.051705
# mental_health_rating    1.0   10.0   5.466447

# %%
df[varNumericas].corr()
# Out:
#                        study_hours_per_day  social_media_hours  netflix_hours  \
# study_hours_per_day               1.000000            0.007364      -0.014493
# social_media_hours                0.007364            1.000000       0.011865
# netflix_hours                    -0.014493            0.011865       1.000000
# attendance_percentage             0.028967            0.049356      -0.015008
# sleep_hours                      -0.026241            0.026861      -0.017006
# exam_score                        0.822950           -0.171672      -0.166578
# age                               0.007150           -0.023854       0.005841
# exercise_frequency               -0.024708           -0.023975      -0.004155
# mental_health_rating             -0.015896           -0.000417      -0.016612
#
#                        attendance_percentage  sleep_hours  exam_score  \
# study_hours_per_day                 0.028967    -0.026241    0.822950
# social_media_hours                  0.049356     0.026861   -0.171672
# netflix_hours                      -0.015008    -0.017006   -0.166578
# attendance_percentage               1.000000     0.001972    0.096005
# sleep_hours                         0.001972     1.000000    0.122294
# exam_score                          0.096005     0.122294    1.000000
# age                                -0.030203     0.040498   -0.012833
# exercise_frequency                 -0.010563     0.030013    0.161397
# mental_health_rating               -0.017096    -0.010653    0.317945
#
#                             age  exercise_frequency  mental_health_rating
# study_hours_per_day    0.007150           -0.024708             -0.015896
# social_media_hours    -0.023854           -0.023975             -0.000417
# netflix_hours          0.005841           -0.004155             -0.016612
# attendance_percentage -0.030203           -0.010563             -0.017096
# sleep_hours            0.040498            0.030013             -0.010653
# exam_score            -0.012833            0.161397              0.317945
# age                    1.000000           -0.005718             -0.052137
# exercise_frequency    -0.005718            1.000000             -0.001500
# mental_health_rating  -0.052137           -0.001500              1.000000

# %% [markdown]
# #### Outliers
# Obtenemos las anomalías y las agregamos a un diccionario que contiene la cantidad de outliers por cada variable.
# En la siguiente celda obtenemos la fila y el valor del outlier respectivamente.
# En la celda subsiguiente recorremos el diccionario de outliers.

# %%
outliers_dict = {}

for columna in varNumericas:
    Q1 = df[columna].quantile(0.25)
    Q3 = df[columna].quantile(0.75)
    IQR = Q3-Q1

    outliers=df[(df[columna]<Q1-IQR*1.5) | (df[columna]>Q3+IQR*1.5)][columna]
    outliers_dict[columna]=outliers
    print(columna, "tiene los siguientes outliers: ")
    print(outliers, "\n")
# Out:
# study_hours_per_day tiene los siguientes outliers:
# 455    8.3
# 797    8.2
# 875    7.6
# Name: study_hours_per_day, dtype: float64
#
# social_media_hours tiene los siguientes outliers:
# 346    6.0
# 361    6.1
# 641    5.7
# 735    7.2
# Name: social_media_hours, dtype: float64
#
# netflix_hours tiene los siguientes outliers:
# 556    5.4
# 822    5.3
# Name: netflix_hours, dtype: float64
#
# attendance_percentage tiene los siguientes outliers:
# 651    57.6
# 706    56.7
# 971    56.0
# Name: attendance_percentage, dtype: float64
#
# sleep_hours tiene los siguientes outliers:
# 955    10.0
# Name: sleep_hours, dtype: float64
#
# exam_score tiene los siguientes outliers:
# 265    18.4
# 327    23.1
# Name: exam_score, dtype: float64
#
# age tiene los siguientes outliers:
# Series([], Name: age, dtype: int64)
#
# exercise_frequency tiene los siguientes outliers:
# Series([], Name: exercise_frequency, dtype: int64)
#
# mental_health_rating tiene los siguientes outliers:
# Series([], Name: mental_health_rating, dtype: int64)

# %%
for columna in outliers_dict:
    print(f"{columna} tiene {len(outliers_dict[columna])} outliers")
# Out:
# study_hours_per_day tiene 3 outliers
# social_media_hours tiene 4 outliers
# netflix_hours tiene 2 outliers
# attendance_percentage tiene 3 outliers
# sleep_hours tiene 1 outliers
# exam_score tiene 2 outliers
# age tiene 0 outliers
# exercise_frequency tiene 0 outliers
# mental_health_rating tiene 0 outliers

# %% [markdown]
# #### Variables categóricas

# %% [markdown]
# Dentro de nuestras variables categóricas la más llamativa es ***gender***. Esta columna principal nos permite visualizar de una mejor manera la muestra obtenida y poder hacer un estudio bastante amplio.
# Estudiaremos el dataset bajo esta variable categórica en las siguientes celdas.

# %%
print("Datos a considerar de las variables categoricas:")
df.describe(include=["object"])
# Out:
# Datos a considerar de las variables categoricas:
#        student_id gender part_time_job diet_quality parental_education_level  \
# count         909    909           909          909                      909
# unique        909      3             2            3                        3
# top         S1000   Male            No         Fair              High School
# freq            1    440           713          396                      392
#
#        internet_quality extracurricular_participation
# count               909                           909
# unique                3                             2
# top                Good                            No
# freq                410                           620

# %% [markdown]
# ##### Análisis de datos en base al género

# %%
df["gender"].value_counts()
# Out:
# gender
# Male      440
# Female    433
# Other      36
# Name: count, dtype: int64

# %%
pd.crosstab(df["gender"], df["age"])
# Out:
# age     17  18  19  20  21  22  23  24
# gender
# Female  53  53  53  70  59  55  42  48
# Male    64  52  46  60  49  45  56  68
# Other    4   4   2   7   6   2   6   5

# %%
sns.countplot(x="gender", data=df)
plt.title("Grafico de barras: Cantidad de personas por Género")
plt.xlabel("Género")
plt.ylabel("Cantidad de personas")
plt.show()

# %%
df.groupby("gender")["exam_score"].agg(["min", "max", "mean"])
# Out:
#          min    max       mean
# gender
# Female  18.4  100.0  69.978522
# Male    23.1  100.0  68.970227
# Other   43.9  100.0  71.688889

# %%
sns.boxplot(data=df, x="gender", y="exam_score")
plt.title("Boxplot: Puntaje de examen por género")
plt.ylabel("Puntaje examen")
plt.xlabel("Género")
plt.show()

# %%
df.groupby("gender")["study_hours_per_day"].agg(["min", "max", "mean"])
# Out:
#         min  max      mean
# gender
# Female  0.0  7.6  3.591917
# Male    0.0  8.3  3.472727
# Other   1.5  5.6  3.705556

# %% [markdown]
# En este apartado podemos notar que los datos están bastante equilibrados, tanto en edad como género. Además, las notas no difieren por mucho entre hombres y mujeres (1 punto), mostrando que no hay una tendencia que se pueda observar de manera evidente.

# %% [markdown]
# #### Visualización de datos y relaciones

# %% [markdown]
# ##### Puntajes examen y horas de estudio

# %% [markdown]
# En las siguientes casillas presentamos dos gráficos que relacionan las horas de estudio con el puntaje obtenido en el examen.

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x="study_hours_per_day", y="exam_score", alpha=0.6)
plt.title("Gráfico de dispersión: Horas de estudio vs Puntaje examen")
plt.ylabel("Puntaje examen")
plt.xlabel("Horas de estudio por día")
plt.show()

# %%
sns.regplot(data=df, x="study_hours_per_day", y="exam_score", scatter=False, color="red")

plt.title("Relación entre horas de estudio y puntaje en el examen", fontsize=12)
plt.xlabel("Horas de estudio por día")
plt.ylabel("Puntaje examen")
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %% [markdown]
# Cómo era de esperarse, hay una relación directa entre estudio y notas. Si bien en el primer gráfico se ve una dispersión importante, hay una clara tendencia a que mayor estudio significa un mejor rendimiento en sus examenes. Por otro lado, el grupo de la muestra con horas de estudio sobre 6 horas es pequeña pero se puede observar que todos los estudiantes pertenecientes a este grupo tienen notas sobresalientes.
# Cómo conclusión inicial, sin mayor análisis, podríamos suponer que lo ideal es estudiar entre 4 y 6 horas, siendo 6 horas donde maximizas la nota.

# %% [markdown]
# ##### Puntaje de examen y salud mental

# %% [markdown]
# La salud mental es un tópico con mucha fuerza en el día de hoy, el impacto estrés y la ansiedad es algo real que debe ser analizado.
#
# Se modela un Diagrama de cajas para ver el rendimiento de los estudiantes basados en su salud mental.

# %%
sns.boxplot(data=df, x="mental_health_rating", y="exam_score")
plt.title("Boxplot: Salud mental vs Puntaje examen final")
plt.xlabel("Nivel de salud mental")
plt.ylabel("Puntaje examen")
plt.show()

# %% [markdown]
# En el siguiente gráfico se analiza la relación entre salud mental y nota. Se ve una tendencia creciente, donde a mejor salud mental mejor rendimiento académico.
# Si bien no hay una tendencia muy empinada, se ve un impacto de la salud mental.

# %% [markdown]
# ##### Datos agrupados

# %% [markdown]
# Los siguientes dos gráficos son datos agrupados, para poder analizarlos se tuvieron que crear nuevas columnas que presentaran los datos dispuestos en intervalos.
# Las nuevas columnas reciben el nombre de ***social_media_group*** y ***study_hours_group***.

# %%
df["social_media_group"] = pd.cut(df["social_media_hours"], bins=[0,2,4,6,8], labels=["0-2h","2-4h","4-6h","6-8h"]) #Se crea la columna con datos agrupados

plt.figure(figsize=(8,6))
sns.stripplot(data=df, x="social_media_group", y="exam_score",
              jitter=True, alpha=0.6, color="purple")

plt.title("Uso de redes sociales (agrupado) vs puntaje")
plt.xlabel("Uso de redes sociales (horas/día)")
plt.ylabel("Puntaje en examen final")

plt.show()

# %% [markdown]
# En el siguiente gráfico se visualizan las horas de uso de redes sociales de forma agrupada (en rangos de dos horas) vs las notas de examen. Se puede visualizar que el grupo con mayor concentración de datos es donde el uso de redes sociales es entre 2 a 4 horas, y se visualiza que la mayor concentración de este grupo está entre 60-80.

# %%
df["study_hours_group"] = pd.cut(df["study_hours_per_day"], bins=[0,2,4,6,8], labels=["0-2h","2-4h","4-6h","6-8h"]) #Se crea la columna con datos agrupados
plt.figure(figsize=(8,6))
sns.stripplot(data=df, x="study_hours_group", y="exam_score",
              jitter=True, alpha=0.6, color="purple")

plt.title("Horas de estudio (agrupado) vs puntaje")
plt.xlabel("Horas de estudio por día")
plt.ylabel("Puntaje en examen final")

plt.show()

# %% [markdown]
# Por último, podemos observar la tendencia entre horas de estudio y puntaje. Se puede observar que hay una minoría que estudia sobre 6 horas, teniendo todos notas sobre 80. Por otra parte pareciera que la diferencia entre el mínimo y el máximo entre los otros grupos se mantiene regular, dando a entender un rango de mejoría de nota según las horas estudiadas.

# %%
df.shape #Primer valor corresponde al número de observaciones
         #Segundo valor corresponde a las columnas
# Out:
# (909, 18)

# %% [markdown]
# ### HIPOTESIS

# %% [markdown]
# *“El rendimiento académico se maximiza cuando existe un equilibrio entre horas de estudio, sueño, salud mental y otros factores, siendo el estudio el factor más determinante.”*
#
# ***
# ***Motivación:***
#
# En la literatura educativa suele asumirse que más horas de estudio = mejor rendimiento académico, pero la realidad muestra que esto no siempre es lineal.
#
# Factores como calidad del sueño, salud mental y balance con el ocio podrían influir en cómo se traducen esas horas de estudio en resultados reales.
#
# Un estudiante que estudia mucho pero duerme poco, o tiene altos niveles de estrés, podría rendir peor que otro con menos estudio pero más equilibrio.
#
# Analizar este fenómeno con datos permite cuantificar qué tanto pesa cada factor y comprobar si efectivamente “solo estudiar más” garantiza mejores resultados.

# %% [markdown]
# # Entrega 2

# %% [markdown]
# ## Estimación Puntual

# %% [markdown]
# En base a nuestra hipótesis, *“El rendimiento académico se maximiza cuando existe un equilibrio entre horas de estudio, sueño, salud mental y otros factores, siendo el estudio el factor más determinante.”*, y a los resultados de correlación de la primera entrega determinamos que el mejor parámetro poblacional para representar esta hipótesis sería la regresión lineal múltiple.
# Los siguientes valores fueron tomados cómo las variables independientes de la regresión:
# - $X_1$: Horas de estudio
# - $X_2$: Salud mental
# - $X_3$: Uso redes sociales
# - $X_4$: Uso de Netflix
# - $X_5$: Horas de sueño
# - $X_6$: Frecuencia de ejercicio
#
# Siguiendo la fórmula de regresión lineal múltiple $\widehat{y} =\ \beta_0 + \beta_1 *X_1 + \beta_2 *X_2 + \beta_3 *X_3 + \beta_4 *X_4 + \beta_5 *X_5 + \beta_6 *X_6$
#
# Este parámetro es muy pertinente al problema de investigación ya que trata, de forma casi directa, la hipótesis planteada. Nosotros, en nuestra pregunta de investigación, planteamos la existencia de un equilibrio entre distintas actividades que maximicen la nota final, y con este parámetro, obtenemos una fórmula que describe este mismo comportamiento.

# %%
cols = [
    "study_hours_per_day",
    "mental_health_rating",
    "social_media_hours",
    "netflix_hours",
    "sleep_hours",
    "exercise_frequency",
    "exam_score"
]

data = df[cols].copy()
n = len(data)

# Asignamos X y Y y agregamos el intercepto
X = data.drop(columns="exam_score").to_numpy(dtype=float)
X = np.column_stack([np.ones(n), X])
Y = data["exam_score"].to_numpy(dtype=float)

#Utilizamos matrices para calcular los beta
XtX = X.T @ X
XtY = X.T @ Y
pendientes = np.linalg.inv(XtX) @ XtY

coef_names = ["Intercepto", "Estudio", "SaludMental",
               "RRSS", "Netflix", "Sueño", "Ejercicio"]

print("\nFórmula de regresión estimada:")
formula = "ŷ = " + " ".join([
    f"{pendientes[i]:.4f}" if i == 0
    else f"{'-' if pendientes[i] < 0 else '+'} {abs(pendientes[i]):.4f}·{coef_names[i]}"
    for i in range(len(pendientes))
])
print(formula)
# Out:
# Fórmula de regresión estimada:
# ŷ = 17.9284 + 9.6239·Estudio + 1.9585·SaludMental - 2.5539·RRSS - 2.2711·Netflix + 2.0112·Sueño + 1.4419·Ejercicio

# %% [markdown]
# Cómo podemos ver, la fórmula indica que sin hacer absolutamente nada, sacarías aproximadamente un 18, siendo la actividad que más aporta estudiar. El estado de la salud mental también aporta, junto a las horas de sueño y ejercicio. Por otro lado las horas de redes sociales y netflix generan un decremento en la nota.
#
# Hablando de sus propiedades básicas, basado en el [Siguiente Articulo](https://www.albert.io/blog/ultimate-properties-of-ols-estimators-guide/) podemos confirmar que esta implementación por matriz (también llamada OLS o [Mínimos Cuadrados Ordinarios](https://www.probabilidadyestadistica.net/regresion-lineal-multiple/)) no es sesgada ya que bajo el supuesto de que el error no está condicionado a variables explicativas (condiciones no evaluadas o "ocultas") se cumplirá y el valor entregado por la muesta coincidirá con el de la población.
#
# El artículo también menciona que es consistente, diciendo que a medida que crezca la muestra se irá acercando al valor real.
#
# Finalmente, en el ámbito de eficiencia, se menciona que éste estimador se le conoce como BLUE (Best Linear Unbiased Estimators) por lo que será eficienciente para resolver lo que se propone.

# %% [markdown]
# ## BOOTSTRAP

# %% [markdown]
# ### Origen y motivación
# El bootstrap fue propuesto por *Bradley Efron* en 1979 como una técnica general de remuestreo para estimar la distribución muestral de un estadístico a partir de la propia muestra observada. La motivación fue resolver problemas donde las fórmulas analíticas para el error, sesgo o intervalos de confianza eran difíciles o inexistentes, aprovechando la creciente capacidad de cómputo para generar muchas remuestras con reemplazo y construir una distribución empírica del estadístico
#
# El bootstrap consiste en generar muchas remuestras con reemplazo de la muestra original, calcular en cada remuestra el estadístico de interés y usar la variabilidad de esos valores para estimar error estándar, sesgo e intervalos de confianza sin asumir una forma paramétrica de la población.
#
# El bootstrapping es ampliamente valioso y se usa especialmente cuando se tiene una muestra pequeña o cuando se desconoce la distribución de esta.
# Actualmente se usa mucho en campos como biología y ciencias médicas, machine learning, ciencia de datos y aplicaciones en estadística sobre estimaciones e inferencias.
# ***

# %% [markdown]
# ### Código
# En el siguiente bloque de código se realiza el método bootstrap que consta de repitir este proceso B veces: en cada iteración toma una muestra con reemplazo de las filas, ajusta nuevamente el modelo OLS (usando la pseudoinversa para evitar problemas numéricos) y almacena los coeficientes obtenidos. Finalmente, para cada coeficiente, calcula la media del bootstrap, el sesgo (media menos 𝛽^​), la desviación estándar empírica, y los intervalos percentiles al nivel de confianza indicado

# %%
def bootstrap_ols(response_col="exam_score", B=5000, ci=0.95, random_state=None):
    """
    Implementación manual del bootstrap para coeficientes OLS por remuestreo de filas.
    Entradas:
      - response_col: nombre de la variable respuesta dentro de cols.
      - B: número de remuestras bootstrap.
      - ci: nivel de confianza (p. ej. 0.95).
      - random_state: semilla entera o None.
    Salida:
      - results: DataFrame con pendientes, media bootstrap, sesgo, se_boot y CI percentil.
      - betas: matriz (B x p) con los coeficientes de cada remuestra.
    """
    p = X.shape[1]
    # Estimador puntual OLS (más estable con solve)
    pendientes = np.linalg.solve(XtX, XtY)
    # Bootstrap
    rng = np.random.default_rng(random_state)
    betas = np.empty((B, p), dtype=float)
    for b in range(B):
        idx = rng.integers(0, n, n)      
        Xb = X[idx]
        Yb = Y[idx]
        XtXb = Xb.T @ Xb
        betas[b] = np.linalg.pinv(XtXb) @ (Xb.T @ Yb)
        
    # Estadísticos bootstrap
    beta_mean = betas.mean(axis=0)
    beta_bias = beta_mean - pendientes
    beta_se = betas.std(axis=0, ddof=1)
    alpha = 1 - ci
    ci_lower = np.percentile(betas, 100 * alpha / 2, axis=0)
    ci_upper = np.percentile(betas, 100 * (1 - alpha / 2), axis=0)

    results = pd.DataFrame({
        "coef": coef_names,
        "pendientes": pendientes,
        "beta_mean_boot": beta_mean,
        "sesgo_boot": beta_bias,
        "se_boot": beta_se,
        f"ci_{100*alpha/2:.1f}%": ci_lower,
        f"ci_{100*(1-alpha/2):.1f}%": ci_upper
    })
    return results, betas

results, betas = bootstrap_ols(response_col="exam_score", B=5000, ci=0.95, random_state=42)
print(results)
# Out:
#           coef  pendientes  beta_mean_boot  sesgo_boot   se_boot    ci_2.5%  \
# 0   Intercepto   17.928398       17.905877   -0.022521  1.393941  15.240643
# 1      Estudio    9.623900        9.625202    0.001302  0.143290   9.347177
# 2  SaludMental    1.958454        1.958996    0.000543  0.067362   1.825253
# 3         RRSS   -2.553879       -2.553312    0.000566  0.166650  -2.882570
# 4      Netflix   -2.271113       -2.266770    0.004343  0.173223  -2.615938
# 5        Sueño    2.011238        2.011522    0.000284  0.152388   1.717392
# 6    Ejercicio    1.441921        1.442951    0.001030  0.092145   1.265784
#
#     ci_97.5%
# 0  20.703282
# 1   9.904373
# 2   2.088563
# 3  -2.236195
# 4  -1.929426
# 5   2.306505
# 6   1.621550

# %% [markdown]
# ***
# A continuación establecemos los parametros para el intervalo de confianza a un  95%.
# Calculamos valores predictivos, residuos entre los valores reales y los predictivos y la varianza del error.
# Calculamos error estandar clásico, estadísticos t y p-valores.
#
# Se_classic mide la incertidumbre de los valores de las pendientes, luego t_stats es el cociente entre los valores por su error, lo que nos indica cuantas desviaciones estándar está el coeficiente lejos de 0.
# p_values mide si el coeficiente (pendiente) es estadísticamente significativo, para esto p_value < 0.05.
#
# Por último se extraen los datos de la función bootstrap previamente implementada.

# %%
from scipy import stats

ci = 0.95
alpha = 1 - ci
yhat = X @ pendientes
resid = Y - yhat
sigma2_hat = (resid**2).sum() / (n - X.shape[1]) 

cov_beta_classic = sigma2_hat * np.linalg.pinv(XtX)
se_classic = np.sqrt(np.diag(cov_beta_classic))
t_stats = pendientes / se_classic
p_values = 2 * stats.t.sf(np.abs(t_stats), df=n - X.shape[1])

# Extraer resultados bootstrap ya calculados
se_boot = results["se_boot"].values
bias_boot = results["sesgo_boot"].values
ci_lower = results["ci_2.5%"].values
ci_upper = results["ci_97.5%"].values

# %% [markdown]
# Ahora procedemos a generar una tabla comparativa con los valores obtenidos por la estimación puntual y el método bootstrap.

# %%
# Tabla comparativa
comp_df = pd.DataFrame({
    "coef": coef_names,
    "pendientes": pendientes,
    "se_classic": se_classic,
    "t": t_stats,
    "p_value": p_values,
    "se_boot": se_boot,
    "sesgo_boot": bias_boot,
    "ci_2.5%": ci_lower,      
    "ci_97.5%": ci_upper      
})
print("\nComparativa clásica vs bootstrap:")
print(comp_df.round(4))
# Out:
# Comparativa clásica vs bootstrap:
#           coef  pendientes  se_classic        t  p_value  se_boot  sesgo_boot  \
# 0   Intercepto     17.9284      1.2971  13.8219      0.0   1.3771     -0.0234
# 1      Estudio      9.6239      0.1259  76.4534      0.0   0.1445      0.0052
# 2  SaludMental      1.9585      0.0647  30.2664      0.0   0.0675      0.0012
# 3         RRSS     -2.5539      0.1588 -16.0812      0.0   0.1655     -0.0022
# 4      Netflix     -2.2711      0.1726 -13.1559      0.0   0.1720     -0.0001
# 5        Sueño      2.0112      0.1518  13.2449      0.0   0.1546      0.0001
# 6    Ejercicio      1.4419      0.0909  15.8631      0.0   0.0908      0.0012
#
#    ci_2.5%  ci_97.5%
# 0  15.2431   20.5391
# 1   9.3444    9.9129
# 2   1.8293    2.0890
# 3  -2.8835   -2.2375
# 4  -2.6104   -1.9321
# 5   1.7154    2.3082
# 6   1.2688    1.6162

# %% [markdown]
# Se puede apreciar que en cada uno de los coeficientes que los valores se_classic y se_boot son muy parecidos, recordar que *se* viene por *standar error* por lo que podemos decir que el estimador es estable.
#
# En cuanto al sesgo del bootstrap es muy cercano a 0 en todas los coeficientes, por lo tanto decimos que el OLS es no sesgado.
#
# El t-valor nos indica que tan significativo es cada coeficiente, podemos ver como todos los coeficientes tienen un t-valor mayor a |10|, siendo el mayor de estos por una amplia diferencia las horas de estudio.
#
# Los intervalos bootstrap nos confirman que las pendientes obtenidas en el análisis OLS son correctos. Estos intervalos nos indican un rango de valores aproximados en los que aumenta o disminuye la nota de examen.

# %% [markdown]
# ### Generación de gráficos

# %%
# Graficar distribuciones bootstrap con β̂ y CI
def plot_boot_dists(betas, pendientes, coef_names, ci_lower, ci_upper, bins=50):
    p = betas.shape[1]
    cols = min(3, p)
    rows = int(np.ceil(p / cols))
    plt.figure(figsize=(4*cols, 3*rows))
    for j in range(p):
        ax = plt.subplot(rows, cols, j+1)
        sns.histplot(betas[:, j], bins=bins, kde=True, stat="density", color="C0", ax=ax)
        ax.axvline(pendientes[j], color="black", linestyle="--", label="β̂")
        ax.axvline(ci_lower[j], color="red", linestyle=":", label=f"CI {100*ci:.0f}%")
        ax.axvline(ci_upper[j], color="red", linestyle=":")
        ax.set_title(coef_names[j])
        ax.legend()
    plt.tight_layout()
    plt.show()

plot_boot_dists(betas, pendientes, coef_names, ci_lower, ci_upper)

# %%
# DataFrame con coeficientes y nombres
coef_df = pd.DataFrame({
    "Variable": coef_names,
    "Pendiente": pendientes
})

plt.figure(figsize=(10, 6))
sns.barplot(
    data=coef_df,
    x="Variable",
    y="Pendiente",
    hue="Variable",          
    palette="coolwarm",
    dodge=False,             
    legend=False             
)

plt.axhline(0, color="black", linewidth=1)
plt.title("Coeficientes estimados del modelo de regresión múltiple", fontsize=14)
plt.xlabel("Variable independiente", fontsize=12)
plt.ylabel("Pendiente (β̂)", fontsize=12)
plt.xticks(rotation=45, ha="right")

plt.tight_layout()
plt.show()

# %%
r2_classic = 1 - (resid**2).sum() / ((Y - Y.mean())**2).sum()
rmse_classic = np.sqrt((resid**2).mean())
print(f"\nR2 clásico: {r2_classic:.4f}   RMSE clásico: {rmse_classic:.4f}")
# Out:
# R2 clásico: 0.8925   RMSE clásico: 5.5483

# %% [markdown]
# ### Conlusión
# Concluimos que la hipótesis planteada: *“El rendimiento académico se maximiza cuando existe un equilibrio entre horas de estudio, sueño, salud mental y otros factores, siendo el estudio el factor más determinante.”* se cumple.
#
# Esto mediante un análisis estadístico OLE y remuestreo bootstrap, los cuales ambos nos dieron valores casi idénticos, lo que demuestra que el estudio realizado OLE era acertado en cuanto al comportamiento de las variables que influyen en la nota final de examen se refiere. No existen diferencias relevantes entre los métodos.
#
# El bootstrap aporta enormemente a la hora de comprobar si el análisis realizado anteriormente era correcto, además que permite extender la muestra y obtener datos acertados en caso de que nuestra muestra fuera pequeña, la cual no es el caso, pero aún así sirve bastante. En cuanto a las limitaciones de este método es que precisamente es de remuestreo, por lo que tiene una dependencia con la muestra original, es decir no se crea nueva información. Otra limitación que se puede dar es que si la muestra es sesgada, el boostrapping hereda el sesgo, nuevamente esto no ocurre en nuestro caso, pero es importante tener esto en consideración.
#
# Notamos por las tablas y gráficos generados que las horas de estudio son el factor dominante, pero un equilibrio con sueño, salud mental y ejercicio contribuye significativamente al rendimiento; el tiempo en ocio (RRSS/Netflix) disminuye el rendimiento.
